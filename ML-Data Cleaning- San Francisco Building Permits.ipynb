# %%
import numpy as np
import pandas as pd

sfPermits = pd.read_csv('./Building_Permits.csv')

# Set seed for reproducibility
np.random.seed(0)
# Out:
# C:\Users\pphuc\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sfPermits.sample(5)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 40553   201403039652            8            otc alterations permit
# 169731  201510159735            3  additions alterations or repairs
# 19180        M409787            8            otc alterations permit
# 68047   201411191888            8            otc alterations permit
# 64238        M527228            8            otc alterations permit
#
#        Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 40553            03/03/2014  3732  008            400                  NaN
# 169731           10/15/2015  2609  028             79                  NaN
# 19180            07/22/2013  4624  031            178                  NaN
# 68047            11/19/2014  0039  109            294                  NaN
# 64238            10/14/2014  1251  002            707                  NaN
#
#         Street Name Street Suffix      ...        Existing Construction Type  \
# ...

# %%
sfPermits.isnull().sum()
# Out:
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %%
sfPermits.head().transpose()
# Out:
#                                                                                         0  \
# Permit Number                                                                201505065519
# Permit Type                                                                             4
# Permit Type Definition                                                       sign - erect
# Permit Creation Date                                                           05/06/2015
# Block                                                                                0326
# Lot                                                                                   023
# Street Number                                                                         140
# Street Number Suffix                                                                  NaN
# Street Name                                                                         Ellis
# ...

# %%
# Calculate total number of cells
totalCells = np.product(sfPermits.shape)
sfPermits.shape
# Out:
# (198900, 43)

# %%
#Count the number of missing values per column
missingCount = sfPermits.isnull().sum()

#Calculate total number of misisng values
totalMissing = missingCount.sum()

# %%
print (missingCount)
print ('Total Missing:',totalMissing)
print ('THe SF Permits dataset contains', round(((totalMissing/totalCells)*100),2),'%','missing values')
# Out:
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %%
sfPermitsCleanCols=sfPermits.dropna(axis=1)
print ('Columns in original dataset',sfPermits.shape[1])
print ('Columns with na dropped',sfPermitsCleanCols.shape[1])
# Out:
# Columns in original dataset 43
# Columns with na dropped 12

# %%
sfPermits.dtypes
# Out:
# Permit Number                              object
# Permit Type                                 int64
# Permit Type Definition                     object
# Permit Creation Date                       object
# Block                                      object
# Lot                                        object
# Street Number                               int64
# Street Number Suffix                       object
# Street Name                                object
# Street Suffix                              object
# Unit                                      float64
# Unit Suffix                                object
# Description                                object
# Current Status                             object
# Current Status Date                        object
# Filed Date                                 object
# Issued Date                                object
# Completed Date                             object
# First Construction Document Date           object
# ...

# %%
for i in sfPermits.columns:
    print ('{} is unique: {}'.format(i,sfPermits[i].is_unique))
# Out:
# Permit Number is unique: False
# Permit Type is unique: False
# Permit Type Definition is unique: False
# Permit Creation Date is unique: False
# Block is unique: False
# Lot is unique: False
# Street Number is unique: False
# Street Number Suffix is unique: False
# Street Name is unique: False
# Street Suffix is unique: False
# Unit is unique: False
# Unit Suffix is unique: False
# Description is unique: False
# Current Status is unique: False
# Current Status Date is unique: False
# Filed Date is unique: False
# Issued Date is unique: False
# Completed Date is unique: False
# First Construction Document Date is unique: False
# Structural Notification is unique: False
# Number of Existing Stories is unique: False
# Number of Proposed Stories is unique: False
# Voluntary Soft-Story Retrofit is unique: False
# Fire Only Permit is unique: False
# Permit Expiration Date is unique: False
# Estimated Cost is unique: False
# Revised Cost is unique: False
# Existing Use is unique: False
# ...

# %%
sfPermits.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix      ...        Existing Construction Type  \
# 0       Ellis            St      ...                               3.0
# ...

# %%
sfPermits.isnull().sum()
# Out:
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %%
sfPermits.describe()
#sfPermits.info
# Out:
#          Permit Type  Street Number          Unit  Number of Existing Stories  \
# count  198900.000000  198900.000000  29479.000000               156116.000000
# mean        7.522323    1121.728944     78.517182                    5.705773
# std         1.457451    1135.768948    326.981324                    8.613455
# min         1.000000       0.000000      0.000000                    0.000000
# 25%         8.000000     235.000000      0.000000                    2.000000
# 50%         8.000000     710.000000      0.000000                    3.000000
# 75%         8.000000    1700.000000      1.000000                    4.000000
# max         8.000000    8400.000000   6004.000000                   78.000000
#
#        Number of Proposed Stories  Estimated Cost  Revised Cost  \
# count               156032.000000    1.608340e+05  1.928340e+05
# mean                     5.745043    1.689554e+05  1.328562e+05
# std                      8.613284    3.630386e+06  3.584903e+06
# ...

# %%
sfPermits.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix      ...        Existing Construction Type  \
# 0       Ellis            St      ...                               3.0
# ...

# %%
# Fill the missing data which is below 1 line exactly the same as the previous line
sfPermits['Proposed Construction Type'].head().fillna(method='pad',limit=1,inplace=True)

# %%
# Fill the missing data which is above 1 line exactly the same as the below line
sfPermits['Proposed Construction Type'].head().fillna(method='bfill',limit=1,inplace=True)

# %%
sfPermits.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix      ...        Existing Construction Type  \
# 0       Ellis            St      ...                               3.0
# ...

# %%
# Drop columns which have at least 90% Non-NANs
sfPermits.dropna(thresh=int(sfPermits.shape[0]*.9),axis=1)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# 5       201706149344            8            otc alterations permit
# 6       201706300814            8            otc alterations permit
# 7            M803667            8            otc alterations permit
# 8            M804227            8            otc alterations permit
# 9            M804767            8            otc alterations permit
# 10           M805287            8            otc alterations permit
# 11           M805907            8            otc alterations permit
# 12           M806447            8            otc alterations permit
# ...

# %%
print( np.where(sfPermits.head()['Permit Type']>5,'smile','sad'))
sfPermits.head()
# Out:
# ['sad' 'sad' 'sad' 'smile' 'smile']
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix      ...        Existing Construction Type  \
# ...

# %%
sfPermits.head().isnull().transpose()
# Out:
#                                             0      1      2      3      4
# Permit Number                           False  False  False  False  False
# Permit Type                             False  False  False  False  False
# Permit Type Definition                  False  False  False  False  False
# Permit Creation Date                    False  False  False  False  False
# Block                                   False  False  False  False  False
# Lot                                     False  False  False  False  False
# Street Number                           False  False  False  False  False
# Street Number Suffix                     True   True   True   True   True
# Street Name                             False  False  False  False  False
# Street Suffix                           False  False  False  False  False
# Unit                                     True  False   True  False   True
# Unit Suffix                              True   True   True   True   True
# ...
